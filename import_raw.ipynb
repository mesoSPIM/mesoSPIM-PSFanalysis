# %%
import numpy as np
from skimage.io import imread, find_available_plugins

# %%
fromraw=np.fromfile('data/transpose_testdata.raw',dtype=np.uint16)

# %%
fromraw.shape
# Out:
# (33672000,)

# %%
def read_metadata(filename):
    pass

# %%
2048*2048*100
# Out:
# 419430400

# %%
# For standard camera data
# fromraw.shape(2048,2048,100)

# %%
fromraw.shape=(100, 732, 460)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context('paper', font_scale=2.0)
sns.set_style('ticks')

# %%
max_image = fromraw.max(axis=2)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(15,15));
#plt.imshow(fromraw[:,:,0],vmin=-10, vmax=256);
plt.imshow(max_image,vmin=0, vmax=1256);
plt.colorbar()

# %%
fromraw.transpose(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-b8742fcddafe> in <module>()
# ----> 1 fromraw.transpose(axis=1)
#
# TypeError: transpose() takes no keyword arguments
